# %% [markdown]
# ## A mini World Bank API Example

# %% [markdown]
# To install World Bank API, execute this line in the command shell:
#
# ```
# pip install wbgapi
# ```
#
# To learn more about the World Bank API, click [here](https://pypi.org/project/wbgapi/).

# %%
import pandas as pd
import wbgapi as wb
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9028/1912002701.py in <module>
#       1 import pandas as pd
# ----> 2 import wbgapi as wb
#
# ModuleNotFoundError: No module named 'wbgapi'

# %% [markdown]
# Choose countries:

# %%
wb.source.info()
# Out:
# id    name                                                                  code      concepts  lastupdated
# ----  --------------------------------------------------------------------  ------  ----------  -------------
# 1     Doing Business                                                        DBS              3  2021-08-18
# 2     World Development Indicators                                          WDI              3  2022-04-08
# 3     Worldwide Governance Indicators                                       WGI              3  2021-09-27
# 5     Subnational Malnutrition Database                                     SNM              3  2016-03-21
# 6     International Debt Statistics                                         IDS              4  2022-01-14
# 11    Africa Development Indicators                                         ADI              3  2013-02-22
# 12    Education Statistics                                                  EDS              3  2020-12-20
# ...

# %%
country_codes = ["GBR","FRA","HUN","PAK","SDN","SMR","THA","TSS","AGO","AFW"] # United Kingdom and France

# %% [markdown]
# Search for identifiers:

# %%
wb.search("Climate change")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9028/3741818658.py in <module>
# ----> 1 wb.search("Climate change")
#
# NameError: name 'wb' is not defined

# %% [markdown]
# We are interested in:
#
# - GDP (current US$)
#
# - Population, total

# %%
indicator_ids = ["SP.URB.TOTL.IN.ZS","NV.AGR.TOTL.ZS", "EG.ELC.ACCS.ZS","AG.LND.IRIG.AG.ZS","SP.URB.TOTL.IN.ZS","SP.URB.TOTL"]

# %% [markdown]
# Display identifiers info:

# %%
wb.series.info(indicator_ids)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9028/2706033162.py in <module>
# ----> 1 wb.series.info(indicator_ids)
#
# NameError: name 'wb' is not defined

# %% [markdown]
# Get the data:

# %%
# specicif time range
df = wb.data.DataFrame(indicator_ids, country_codes, time=range(2016, 2021))
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9028/1071735881.py in <module>
#       1 # specicif time range
# ----> 2 df = wb.data.DataFrame(indicator_ids, country_codes, time=range(2016, 2021))
#       3 df
#
# NameError: name 'wb' is not defined

# %%
# most recent years
df =  wb.data.DataFrame(indicator_ids, country_codes, mrv=5)
df
# Out:
# C:\Users\LENOVO\AppData\Local\Programs\Python\Python310\lib\site-packages\wbgapi\data.py:327: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   dummy = pd.Series()    # empty series - never assigned actual values
#                                  YR2016        YR2017        YR2018  \
# economy series
# AFW     AG.LND.IRIG.AG.ZS           NaN           NaN           NaN
#         EG.ELC.ACCS.ZS     5.094894e+01  4.884820e+01  5.125325e+01
#         NV.AGR.TOTL.ZS     2.100622e+01  2.080529e+01  2.093141e+01
#         SP.URB.TOTL        1.873058e+08  1.950161e+08  2.029611e+08
#         SP.URB.TOTL.IN.ZS  4.540181e+01  4.601933e+01  4.663314e+01
# AGO     AG.LND.IRIG.AG.ZS           NaN           NaN           NaN
#         EG.ELC.ACCS.ZS     4.179738e+01  4.300161e+01  4.529000e+01
#         NV.AGR.TOTL.ZS     9.831169e+00  1.001700e+01  8.607742e+00
# ...

# %%
# Eliminating the NaN Values
df.dropna()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9028/2313764871.py in <module>
#       1 # Eliminating the NaN Values
# ----> 2 df.dropna()
#
# NameError: name 'df' is not defined

# %%
# Statistical Description of the retrieved dataset
df.describe().T
# Out:
#         count          mean           std       min        25%        50%  \
# YR2016   42.0  2.003014e+07  6.828030e+07  0.013624  25.941649  57.548969
# YR2017   42.0  2.071658e+07  7.101277e+07  0.020479  25.786901  57.747232
# YR2018   43.0  2.092498e+07  7.302472e+07  0.016407  22.424559  53.223140
# YR2019   40.0  2.325671e+07  7.852342e+07  0.015277  31.695213  68.910500
# YR2020   29.0  3.315871e+07  9.465962e+07  0.581796  23.004831  66.825000
#
#                 75%          max
# YR2016       100.00  399975528.0
# YR2017       100.00  416335563.0
# YR2018       100.00  433237352.0
# YR2019      8318.25  450673306.0
# YR2020  15458183.00  468643630.0

# %%
# Capturing the Time series dataset
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize = (10, 6))
wb.data.DataFrame('SP.URB.TOTL', economy=wb.region.members('SAS'), time=range (2016, 2020), numericTimeKeys=True, labels=True).set_index('Country').transpose().plot(title='Income growth in South Africa')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9028/3001280789.py in <module>
#       3 from matplotlib.pyplot import figure
#       4 figure(figsize = (10, 6))
# ----> 5 wb.data.DataFrame('SP.URB.TOTL', economy=wb.region.members('SAS'), time=range (2016, 2020), numericTimeKeys=True, labels=True).set_index('Country').transpose().plot(title='Income growth in South Africa')
#
# NameError: name 'wb' is not defined

# %%
wb.data.DataFrame('SP.URB.TOTL', ["GBR","FRA","HUN","PAK","SDN","SMR","THA","TSS","AGO","AFW"], time=range(2016,2020),numericTimeKeys=True).transpose().plot()
# Out:
# C:\Users\LENOVO\AppData\Local\Programs\Python\Python310\lib\site-packages\wbgapi\data.py:327: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   dummy = pd.Series()    # empty series - never assigned actual values
# <AxesSubplot:>

# %%
# Creating the series dataframe
df_c = df.groupby('series')
df_c.head()
df_c.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9028/1172311451.py in <module>
#       1 # Creating the series dataframe
# ----> 2 df_c = df.groupby('series')
#       3 df_c.head()
#       4 df_c.describe()
#
# NameError: name 'df' is not defined

# %%
df.dropna()
# Out:
#                                  YR2016        YR2017        YR2018  \
# economy series
# AFW     NV.AGR.TOTL.ZS     2.100622e+01  2.080529e+01  2.093141e+01
#         SP.URB.TOTL        1.873058e+08  1.950161e+08  2.029611e+08
#         SP.URB.TOTL.IN.ZS  4.540181e+01  4.601933e+01  4.663314e+01
# AGO     NV.AGR.TOTL.ZS     9.831169e+00  1.001700e+01  8.607742e+00
#         SP.URB.TOTL        1.850216e+07  1.933290e+07  2.018472e+07
#         SP.URB.TOTL.IN.ZS  6.414900e+01  6.483900e+01  6.551400e+01
# FRA     NV.AGR.TOTL.ZS     1.437115e+00  1.542415e+00  1.648877e+00
#         SP.URB.TOTL        5.332390e+07  5.365487e+07  5.397948e+07
#         SP.URB.TOTL.IN.ZS  7.991700e+01  8.018000e+01  8.044400e+01
# GBR     NV.AGR.TOTL.ZS     5.668345e-01  5.933787e-01  5.766241e-01
#         SP.URB.TOTL        5.438282e+07  5.492332e+07  5.542660e+07
#         SP.URB.TOTL.IN.ZS  8.288600e+01  8.314300e+01  8.339800e+01
# HUN     NV.AGR.TOTL.ZS     3.889340e+00  3.753567e+00  3.485912e+00
# ...

# %%
# Determining the Correlation coefficient
corr_Coeff=df.corr(method ='pearson')
corr_Coeff
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9028/3749594310.py in <module>
#       1 # Determining the Correlation coefficient
# ----> 2 corr_Coeff=df.corr(method ='pearson')
#       3 corr_Coeff
#
# NameError: name 'df' is not defined

# %%
# Correlation plot
corr_Coeff.style.background_gradient(cmap='coolwarm')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9028/3894386031.py in <module>
#       1 # Correlation plot
# ----> 2 corr_Coeff.style.background_gradient(cmap='coolwarm')
#
# NameError: name 'corr_Coeff' is not defined
